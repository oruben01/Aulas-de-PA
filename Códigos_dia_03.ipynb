# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Programas-e-Algoritimos/blob/main/C%C3%B3digos_dia_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.randint(0,10)

print (a)
# Out:
# 8

# %%
import random

a = random.random()

print (a)
# Out:
# 0.6743595061152593

# %%
# jogo de adivinhação

# o usuario tera 03 chances de adivinhas um numero de 0 a 10
# se o numero digitado for maior ou menor que o numero secreto o programa imprime uma mensagem informando
# informar se o palpite esta quente ou frio
