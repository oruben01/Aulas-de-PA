# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Aulas-de-PA/blob/main/Aula_de_PA_08_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada

numero = int(input("Digite um número: "))

# Processamento e Saída

if numero % 2 == 0:
  print (f"O número {numero}, é um número par. ")
else:
  print (f"O número {numero}, é um número ímpar. ")
# Out:
# Digite um número: 1999
# O número 1999, é um número ímpar.

# %%
# Escrever um programa que o usuário digita o nome e suas 04 notas referente aos bimestres, calcula a média e mostra
# aprovado, recuperação ou reprovado.
# Nota maior ou igual a 7 aprovado;
# Nota maior ou igual a 5 e menor que 7 recuperação;
#nota menor que 5 reprovado;

#Entrada

nome = str (input("Digite seu nome:"))
nota1 = float (input("Digite sua nota do 1º bimestre:"))
if nota1 > 10:
  print("Digite uma nota válida (notas de 0 a 10)")
nota2 = float (input("Digite sua nota do 2º bimestre:"))
if nota2 > 10:
  print("Digite uma nota válida (notas de 0 a 10)")
nota3 = float (input("Digite sua nota do 3º bimestre:"))
if nota3 > 10:
  print("Digite uma nota válida (notas de 0 a 10)")
nota4 = float (input("Digite sua nota do 4º bimestre:"))
if nota4 > 10:
  print("Digite uma nota válida (notas de 0 a 10)")

media = (nota1 + nota2 + nota3 + nota4) / 4

# Processamento


if media >= 7:
  print (f"A média de suas notas {nome}, foi {media}, você foi aprovado.")

elif media >= 5:
  print (f"A média de suas notas {nome}, foi {media}, você está de recuperação.")

else:
  print (f"A média de suas notas {nome}, foi {media}, você foi REPROVADO.")

# Saída
# Out:
# Digite seu nome:Ruben
# Digite sua nota do 1º bimestre:8
# Digite sua nota do 2º bimestre:9
# Digite sua nota do 3º bimestre:10
# Digite sua nota do 4º bimestre:7
# A média de suas notas Ruben, foi 8.5, você foi aprovado.

# %%
# Entrada
lado1 = float(input("Digite o comprimento do primeiro lado:"))
print(" ")

lado2 = float(input("Digite o comprimento do segundo lado:"))
print(" ")

lado3 = float(input("Digite o comprimento do terceiro lado:"))
print(" ")


# Processamento e Saída

if (lado1 + lado2 > lado3) and (lado1 + lado3 > lado2) and (lado2 + lado3 > lado1):
  print("É um triângulo válido!")
  print(" ")
  print(" ")

  if lado1 == lado2 and lado2 == lado3:
    print("É um triângulo Equilátero.")

  elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    print("É um triângulo Isósceles.")

  else:
    print("É um triângulo Escaleno.")

else:
  print("Não é um triângulo válido.")
# Out:
# Digite o comprimento do primeiro lado:10
#
# Digite o comprimento do segundo lado:10
#
# Digite o comprimento do terceiro lado:10
#
# É um triângulo válido!
#
#
# É um triângulo Equilátero.
